# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Preproccesing

# %%
df = pd.read_csv('train.csv')
# численные признаки
num_cols = [
    'ClientPeriod',
    'MonthlySpending',
    'TotalSpent'
]

# Категориальные признаки
cat_cols = [
    'Sex',
    'IsSeniorCitizen',
    'HasPartner',
    'HasChild',
    'HasPhoneService',
    'HasMultiplePhoneNumbers',
    'HasInternetService',
    'HasOnlineSecurityService',
    'HasOnlineBackup',
    'HasDeviceProtection',
    'HasTechSupportAccess',
    'HasOnlineTV',
    'HasMovieSubscription',
    'HasContractPhone',
    'IsBillingPaperless',
    'PaymentMethod'
]

feature_cols = num_cols + cat_cols # все признаки кроме целевой переменной
target_col = 'Churn' # целевая переменная

# %%
df = df.replace('?', np.nan) # меняем все ? на NaN
df = df.replace(' ', np.nan) # меняем все пробелы на NaN
df.isna().sum().sum() # считаем количество NaN во всем датасете
# Out:
# 9

# %% [markdown]
# ### Их 9, удаляем все строки содержащие NaN's и проверяем снова на наличие NaN'ов:

# %%
df = df.dropna()
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Теперь их ноль, отлично, дальше нужно преобразовать все численные данные к числам (float)

# %%
df[num_cols] = df[num_cols].apply(pd.to_numeric)

# %% [markdown]
# ## Теперь оценим распределение числовых признаков:

# %%
fig, ax = plt.subplots(1,3, sharey=True, tight_layout=True) 
ax[0].hist(df['ClientPeriod'])
ax[1].hist(df['MonthlySpending'])
ax[2].hist(df['TotalSpent'])
ax[0].set_title('ClientPeriod')
ax[1].set_title('MonthlySpending')
ax[2].set_title('TotalSpent')
ax[0].set_ylabel('Frequency')
fig.suptitle('Distrubution of numeric features')
plt.show()
None

# %% [markdown]
# ### Фича ClientPeriod и MonthlySpending распределены более равномерно чем TotalSpent
# ### Теперь посмотрим на категориальные признаки:

# %%
cat_col_values = [0] * len(cat_cols)
for i in range(len(cat_cols)):
    cat_col_values[i] = [j for j in df[cat_cols[i]].value_counts()]
cat_col_labels = [0] * len(cat_cols)
for i in range(len(cat_cols)):
    cat_col_labels[i] = set(df[cat_cols[i]].tolist()) 
ctr = 0 
fig, ax = plt.subplots(2,2, figsize=(10,10))
fig.suptitle('Destribution of categorical features [Part 1]')

for i in range(2):
    for j in range(2):
        ax[i,j].pie(cat_col_values[ctr], labels=cat_col_labels[ctr], autopct='%.1f%%', shadow=True, radius=1)
        ax[i,j].set_title(cat_cols[ctr])
        ctr += 1

# %%
fig, ax = plt.subplots(2,2, figsize=(10,10))

fig.suptitle('Destribution of categorical features [Part 2]')
for i in range(2):
    for j in range(2):
        ax[i,j].pie(cat_col_values[ctr], labels=cat_col_labels[ctr], autopct='%.1f%%', shadow=True, radius=1)
        ax[i,j].set_title(cat_cols[ctr])
        ctr += 1

# %%
fig, ax = plt.subplots(2,2, figsize=(10,10))
 
fig.suptitle('Destribution of categorical features [Part 3]')
for i in range(2):
    for j in range(2):
        ax[i,j].pie(cat_col_values[ctr], labels=cat_col_labels[ctr], autopct='%.1f%%', shadow=True, radius=1)
        ax[i,j].set_title(cat_cols[ctr])
        ctr += 1

# %%
fig, ax = plt.subplots(2,2, figsize=(10,10))
 
fig.suptitle('Destribution of categorical features [Part 4]')
for i in range(2):
    for j in range(2):
        ax[i,j].pie(cat_col_values[ctr], labels=cat_col_labels[ctr], autopct='%.1f%%', shadow=True, radius=1)
        ax[i,j].set_title(cat_cols[ctr])
        ctr += 1

# %% [markdown]
# ### HasPhoneService и IsSeniorCitizen распределены крайне неравномерно и по хорошему требуют какой то обработки, возможно даже удаления, но мы этого делать не будем:)

# %% [markdown]
# ### Далее оценим распределение целевой переменной:

# %%
fig, ax = plt.subplots(1,1, figsize=(5,5))
 
fig.suptitle('Destribution of target variable')
target_values = [df.Churn.value_counts()[0], df.Churn.value_counts()[1]]
ax.pie(target_values, labels=[1,0], autopct='%.1f%%', shadow=True, radius=1, explode = [0, 0.1])
None

# %%
legend = ['1', '0']

one = np.ones(df.Churn.value_counts()[0])
zero = np.zeros(df.Churn.value_counts()[1])

x = [0,1]

plt.hist(one, bins = 1)
plt.hist(zero, bins = 1)

plt.xlabel("Churn")
plt.ylabel("Count")
plt.legend(legend)
plt.title('Distribution of target variable') 

default_x_ticks = range(len(x))
plt.xticks(default_x_ticks, x)

plt.show()
None

# %% [markdown]
# ### Целевая переменная также распределена неравномерно, следовательно метрику accuracy использовать не стоит

# %% [markdown]
# ### Разбиваем датафрейм на 3 подгруппы: те что содержат численные данные, категориальные, ну и собственно вектор целевой переменной:

# %%
numeric_data = df[num_cols]
categorical_data = df[cat_cols]
target_column = df[target_col]

# %% [markdown]
# ### Проводим one-hot-encodind категориальных фичей:

# %%
dummy_features = pd.get_dummies(categorical_data) 
X = pd.concat([numeric_data, dummy_features], axis = 1)
X_with_target = pd.concat([numeric_data, dummy_features, target_column], axis = 1)
X_origin = df.iloc[:,:-1]
y = df[target_col]
print("Shape of df before one-hot-encoding: " + str(X_origin.shape))
print("Shape of df after one-hot-encoding: " + str(X.shape))
# Out:
# Shape of df before one-hot-encoding: (5273, 19)
# Shape of df after one-hot-encoding: (5273, 45)

# %% [markdown]
# ### Как мы видим после преобразования категориальных фичей количество признаков увеличилось с 19 до 45!

# %% [markdown]
# ### И посмотрим на корреляцию между признаками, фокус внимания на строку Churn. Самая сильная корреляция с HasContractPhone_Month-to-month - 0.4; ClienPeriod и HasOnlineSecurityService_No по 0.35

# %%
X_with_target.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\neuropromotion\AppData\Local\Temp\ipykernel_20412\2459831004.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   X_with_target.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_e9197_row0_col0, #T_e9197_row1_col1, #T_e9197_row2_col2, #T_e9197_row3_col3, #T_e9197_row4_col4, #T_e9197_row5_col5, #T_e9197_row6_col6, #T_e9197_row7_col7, #T_e9197_row8_col8, #T_e9197_row9_col9, #T_e9197_row10_col10, #T_e9197_row10_col13, #T_e9197_row11_col11, #T_e9197_row12_col12, #T_e9197_row13_col10, #T_e9197_row13_col13, #T_e9197_row14_col14, #T_e9197_row15_col15, #T_e9197_row16_col16, #T_e9197_row17_col17, #T_e9197_row17_col19, #T_e9197_row17_col22, #T_e9197_row17_col25, #T_e9197_row17_col28, #T_e9197_row17_col31, #T_e9197_row17_col34, #T_e9197_row18_col18, #T_e9197_row19_col17, #T_e9197_row19_col19, #T_e9197_row19_col22, #T_e9197_row19_col25, #T_e9197_row19_col28, #T_e9197_row19_col31, #T_e9197_row19_col34, #T_e9197_row20_col20, #T_e9197_row21_col21, #T_e9197_row22_col17, #T_e9197_row22_col19, #T_e9197_row22_col22, #T_e9197_row22_col25, #T_e9197_row22_col28, #T_e9197_row22_col31, #T_e9197_row22_col34, #T_e9197_row23_col23, #T_e9197_row24_col24, #T_e9197_row25_col17, #T_e9197_row25_col19, #T_e9197_row25_col22, #T_e9197_row25_col25, #T_e9197_row25_col28, #T_e9197_row25_col31, #T_e9197_row25_col34, #T_e9197_row26_col26, #T_e9197_row27_col27, #T_e9197_row28_col17, #T_e9197_row28_col19, #T_e9197_row28_col22, #T_e9197_row28_col25, #T_e9197_row28_col28, #T_e9197_row28_col31, #T_e9197_row28_col34, #T_e9197_row29_col29
_row13_col4, #T_e9197_row13_col8, #T_e9197_row15_col21, #T_e9197_row16_col23, #T_e9197_row20_col5, #T_e9197_row20_col32, #T_e9197_row20_col40, #T_e9197_row21_col15, #T_e9197_row23_col16, #T_e9197_row26_col38, #T_e9197_row27_col4, #T_e9197_row30_col4, #T_e9197_row32_col5, #T_e9197_row35_col5, #T_e9197_row35_col18, #T_e9197_row37_col4, #T_e9197_row38_col5, #T_e9197_row40_col36, #T_e9197_row41_col5, #T_e9197_row41_col10, #T_e9197_row41_col13, #T_e9197_row41_col14, #T_e9197_row42_col40, #T_e9197_row43_col14, #T_e9197_row44_col4, #T_e9197_row44_col11, #T_e9197_row45_col5, #T_e9197_row45_col10, #T_e9197_row45_col13, #T_e9197_row45_col43 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_e9197_row0_col11, #T_e9197_row1_col4, #T_e9197_row3_col5, #T_e9197_row3_col11, #T_e9197_row4_col8, #T_e9197_row4_col11, #T_e9197_row5_col9, #T_

# %% [markdown]
# ### Импортируем необходимые библиотеки и переходим к разбиению датасета на тренировочный и валидационный:

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Делим выборку на тестовую и тренировочную:

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, train_size = 0.8, random_state = 42)

# %% [markdown]
# ### Переписываем функцию из семинара)

# %%
def search_and_draw(X,y, model, param_name, grid, param_scale='ordinary', draw=True):
    parameters = {param_name: grid}
    
    CV_model = GridSearchCV(estimator = model,
                           param_grid=parameters,
                           cv=6,
                           scoring='roc_auc',
                           n_jobs=-1,
                           verbose=10)
    CV_model.fit(X, y)
    means = CV_model.cv_results_['mean_test_score']
    error = CV_model.cv_results_['std_test_score']
    
    if draw:
        plt.figure(figsize=(15,8))
        plt.title('choose ' + param_name)
        
        if (param_scale == 'log'):
            plt.xscale('log')
            
        plt.plot(grid, means, label='mean values of score', color='red', lw=3)
        
        plt.fill_between(grid, means - 2 * error, means + 2 * error,
                        color='green', label='filled area between errors',
                        alpha=0.5)
        legend_box = plt.legend(framealpha=1).get_frame()
        legend_box.set_facecolor('white')
        legend_box.set_edgecolor('black')
        plt.xlabel('parameter')
        plt.ylabel('roc_auc')
        plt.show()
        
    return means, error

# %% [markdown]
# ### Создаем шаблоны моделей, будем использовать логистическую регрессию, KNN и решающее дерево. Далее передаем все параметры в функцию и запускаем

# %%
models = [LogisticRegression(max_iter=1000), KNeighborsClassifier(), DecisionTreeClassifier()]
param_names = ['C', 'n_neighbors', 'max_depth']
grids = [np.array([100, 10, 1, 0.1, 0.01, 0.001, 0.0001]), np.array(np.linspace(4,30,8), dtype='int'), np.arange(1,30)]
param_scales = ['ordinary', 'ordinary', 'ordinary']



for model, param_name, grid, param_scale in zip(models, param_names, grids, param_scales):
    search_and_draw(X_train, y_train, model, param_name, grid, param_scale)
# Out:
# Fitting 6 folds for each of 7 candidates, totalling 42 fits
# Fitting 6 folds for each of 8 candidates, totalling 48 fits
# Fitting 6 folds for each of 29 candidates, totalling 174 fits

# %% [markdown]
# ### Как мы видим лучше всего с задачей справился алгоритм линейной регрессии, чуть хуже решаюшее дерево и хуже всех KNN. Причем качества алгоритма решающего дерева начало падать после глубины свыше 4-5. Посмотрим как изменяться результаты после нормировки данных

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
for model, param_name, grid, param_scale in zip(models, param_names, grids, param_scales):
    search_and_draw(X_train_scaled, y_train, model, param_name, grid, param_scale)
# Out:
# Fitting 6 folds for each of 7 candidates, totalling 42 fits
# Fitting 6 folds for each of 8 candidates, totalling 48 fits
# Fitting 6 folds for each of 29 candidates, totalling 174 fits

# %% [markdown]
# ### Помоему ничего не поменялось ... Теперь создадим модель на базе catboost, логистическую регрессию и попробуем logistic regression CV, далее с помощью метрики roc_auc и алгоритма из семинара оценим эффективность алгоритмов:

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# %%
def test_and_draw(y_train_pred, y_test_pred):
    train_auc = roc_auc_score(y_train, y_train_pred)
    test_auc = roc_auc_score(y_test, y_test_pred)

    plt.figure(figsize=(20,10))
    plt.plot(*roc_curve(y_train, y_train_pred)[:2], label='train AUC={:.4f}'.format(train_auc))
    plt.plot(*roc_curve(y_test, y_test_pred)[:2], label='test AUC={:.4f}'.format(test_auc))
    legend_box = plt.legend(fontsize='large', framealpha=1).get_frame()
    legend_box.set_facecolor('white')
    legend_box.set_edgecolor('black')
    plt.plot(np.linspace(0,1,100), np.linspace(0,1,100))
    plt.show()

# %%
lr = LogisticRegression(max_iter=1000, C = 20)

lr.fit(X_train, y_train)
y_train_predicted_lr = lr.predict_proba(X_train)[:, 1]
y_test_predicted_lr = lr.predict_proba(X_test)[:, 1]

# %%
from catboost import CatBoostClassifier
cb = CatBoostClassifier(eval_metric='AUC', depth=10, iterations=250, learning_rate=0.01, silent=False) 
cb.fit(X_train, y_train)

y_train_predicted_cb = cb.predict_proba(X_train)[:, 1]
y_test_predicted_cb = cb.predict_proba(X_test)[:, 1]
# Out:
# 0:	total: 24.7ms	remaining: 6.15s
# 1:	total: 48ms	remaining: 5.95s
# 2:	total: 72.7ms	remaining: 5.99s
# 3:	total: 98.4ms	remaining: 6.05s
# 4:	total: 123ms	remaining: 6.03s
# 5:	total: 149ms	remaining: 6.06s
# 6:	total: 176ms	remaining: 6.1s
# 7:	total: 185ms	remaining: 5.58s
# 8:	total: 192ms	remaining: 5.15s
# 9:	total: 216ms	remaining: 5.18s
# 10:	total: 244ms	remaining: 5.3s
# 11:	total: 284ms	remaining: 5.64s
# 12:	total: 293ms	remaining: 5.34s
# 13:	total: 311ms	remaining: 5.25s
# 14:	total: 338ms	remaining: 5.29s
# 15:	total: 363ms	remaining: 5.31s
# 16:	total: 377ms	remaining: 5.17s
# 17:	total: 401ms	remaining: 5.17s
# 18:	total: 424ms	remaining: 5.15s
# 19:	total: 448ms	remaining: 5.16s
# 20:	total: 474ms	remaining: 5.16s
# 21:	total: 500ms	remaining: 5.19s
# 22:	total: 527ms	remaining: 5.2s
# 23:	total: 553ms	remaining: 5.21s
# 24:	total: 577ms	remaining: 5.19s
# 25:	total: 602ms	remaining: 5.19s
# 26:	total: 626ms	remaining: 5.17s
# 27:	total: 649ms	remaining: 5.15s
# 28:	total: 680ms	remaining: 5.18s
# 29:	total: 704ms	remaining: 5.17s
# 30:	total: 729ms	remaining: 5.15s
# 31:	total: 743ms	remaining: 5.06s
# 32:	total: 767ms	remaining: 5.04s
# 33:	total: 775ms	remaining: 4.92s
# 34:	total: 779ms	remaining: 4.78s
# 35:	total: 803ms	remaining: 4.78s
# 36:	total: 830ms	remaining: 4.78s
# 37:	total: 862ms	remaining: 4.81s
# 38:	total: 893ms	remaining: 4.83s
# 39:	total: 918ms	remaining: 4.82s
# 40:	total: 945ms	remaining: 4.82s
# 41:	total: 977ms	remaining: 4.84s
# 42:	total: 1s	remaining: 4.83s
# 43:	total: 1.03s	remaining: 4.82s
# 44:	total: 1.06s	remaining: 4.81s
# 45:	total: 1.08s	remaining: 4.81s
# 46:	total: 1.11s	remaining: 4.81s
# 47:	total: 1.14s	remaining: 4.81s
# 48:	total: 1.17s	remaining: 4.81s
# 49:	total: 1.17s	remaining: 4.7s
# 50:	total: 1.2s	remaining: 4.69s
# 51:	total: 1.23s	remaining: 4.68s
# 52:	total: 1.27s	remaining: 4.73s
# 53:	total: 1.3s	remaining: 4.72s
# 54:	total: 1.32s	remaining: 4.7s
# 55:	total: 1.35s	remaining: 4.69s
# 56:	total: 1.38s	remaining: 4.67s
# 57:	total: 1.4s	remaining: 4.65s
# 58:	total: 1.41s	remaining: 4.56s
# 59:	total: 1.43s	remaining: 4.54s
# 60:	total: 1.46s	remaining: 4.52s
# 61:	total: 1.48s	remaining: 4.5s
# 62:	total: 1.51s	remaining: 4.48s
# 63:	total: 1.54s	remaining: 4.47s
# 64:	total: 1.56s	remaining: 4.45s
# 65:	total: 1.59s	remaining: 4.45s
# 66:	total: 1.6s	remaining: 4.37s
# 67:	total: 1.63s	remaining: 4.35s
# 68:	total: 1.65s	remaining: 4.34s
# 69:	total: 1.68s	remaining: 4.32s
# 70:	total: 1.71s	remaining: 4.31s
# 71:	total: 1.74s	remaining: 4.29s
# 72:	total: 1.76s	remaining: 4.28s
# 73:	total: 1.79s	remaining: 4.26s
# 74:	total: 1.82s	remaining: 4.24s
# 75:	total: 1.84s	remaining: 4.22s
# 76:	total: 1.87s	remaining: 4.2s
# 77:	total: 1.89s	remaining: 4.18s
# 78:	total: 1.92s	remaining: 4.16s
# 79:	total: 1.95s	remaining: 4.14s
# 80:	total: 1.97s	remaining: 4.12s
# 81:	total: 2s	remaining: 4.1s
# 82:	total: 2.03s	remaining: 4.08s
# 83:	total: 2.06s	remaining: 4.06s
# 84:	total: 2.08s	remaining: 4.04s
# 85:	total: 2.11s	remaining: 4.03s
# 86:	total: 2.15s	remaining: 4.03s
# 87:	total: 2.18s	remaining: 4.02s
# 88:	total: 2.21s	remaining: 4.01s
# 89:	total: 2.24s	remaining: 3.98s
# 90:	total: 2.27s	remaining: 3.96s
# 91:	total: 2.29s	remaining: 3.94s
# 92:	total: 2.32s	remaining: 3.91s
# 93:	total: 2.34s	remaining: 3.89s
# 94:	total: 2.37s	remaining: 3.86s
# 95:	total: 2.39s	remaining: 3.84s
# 96:	total: 2.42s	remaining: 3.82s
# 97:	total: 2.44s	remaining: 3.79s
# 98:	total: 2.47s	remaining: 3.77s
# 99:	total: 2.49s	remaining: 3.74s
# 100:	total: 2.52s	remaining: 3.71s
# 101:	total: 2.54s	remaining: 3.69s
# 102:	total: 2.57s	remaining: 3.66s
# 103:	total: 2.59s	remaining: 3.64s
# 104:	total: 2.62s	remaining: 3.62s
# 105:	total: 2.65s	remaining: 3.6s
# 106:	total: 2.67s	remaining: 3.57s
# 107:	total: 2.7s	remaining: 3.55s
# 108:	total: 2.73s	remaining: 3.53s
# 109:	total: 2.76s	remaining: 3.51s
# 110:	total: 2.78s	remaining: 3.48s
# 111:	total: 2.81s	remaining: 3.46s
# 112:	total: 2.83s	remaining: 3.44s
# 113:	total: 2.87s	remaining: 3.42s
# 114:	total: 2.89s	remaining: 3.39s
# 115:	total: 2.92s	remaining: 3.37s
# 116:	total: 2.94s	remaining: 3.35s
# 117:	total: 2.97s	remaining: 3.32s
# 118:	total: 3s	remaining: 3.3s
# 119:	total: 3.02s	remaining: 3.27s
# 120:	total: 3.05s	remaining: 3.25s
# 121:	total: 3.08s	remaining: 3.23s
# 122:	total: 3.08s	remaining: 3.18s
# 123:	total: 3.1s	remaining: 3.15s
# 124:	total: 3.13s	remaining: 3.13s
# 125:	total: 3.16s	remaining: 3.11s
# 126:	total: 3.18s	remaining: 3.08s
# 127:	total: 3.21s	remaining: 3.06s
# 128:	total: 3.23s	remaining: 3.03s
# 129:	total: 3.26s	remaining: 3.01s
# 130:	total: 3.29s	remaining: 2.98s
# 131:	total: 3.31s	remaining: 2.96s
# 132:	total: 3.33s	remaining: 2.93s
# 133:	total: 3.36s	remaining: 2.91s
# 134:	total: 3.38s	remaining: 2.88s
# 135:	total: 3.41s	remaining: 2.85s
# 136:	total: 3.43s	remaining: 2.83s
# 137:	total: 3.46s	remaining: 2.8s
# 138:	total: 3.48s	remaining: 2.78s
# 139:	total: 3.51s	remaining: 2.75s
# 140:	total: 3.53s	remaining: 2.73s
# 141:	total: 3.56s	remaining: 2.7s
# 142:	total: 3.58s	remaining: 2.68s
# 143:	total: 3.6s	remaining: 2.65s
# 144:	total: 3.63s	remaining: 2.63s
# 145:	total: 3.66s	remaining: 2.6s
# 146:	total: 3.68s	remaining: 2.58s
# 147:	total: 3.71s	remaining: 2.56s
# 148:	total: 3.74s	remaining: 2.53s
# 149:	total: 3.76s	remaining: 2.51s
# 150:	total: 3.79s	remaining: 2.48s
# 151:	total: 3.81s	remaining: 2.46s
# 152:	total: 3.84s	remaining: 2.43s
# 153:	total: 3.87s	remaining: 2.41s
# 154:	total: 3.89s	remaining: 2.38s
# 155:	total: 3.92s	remaining: 2.36s
# 156:	total: 3.94s	remaining: 2.34s
# 157:	total: 3.97s	remaining: 2.31s
# 158:	total: 4s	remaining: 2.29s
# 159:	total: 4.03s	remaining: 2.27s
# 160:	total: 4.05s	remaining: 2.24s
# 161:	total: 4.08s	remaining: 2.22s
# 162:	total: 4.12s	remaining: 2.2s
# 163:	total: 4.12s	remaining: 2.16s
# 164:	total: 4.16s	remaining: 2.14s
# 165:	total: 4.19s	remaining: 2.12s
# 166:	total: 4.22s	remaining: 2.1s
# 167:	total: 4.24s	remaining: 2.07s
# 168:	total: 4.27s	remaining: 2.05s
# 169:	total: 4.3s	remaining: 2.02s
# 170:	total: 4.33s	remaining: 2s
# 171:	total: 4.36s	remaining: 1.98s
# 172:	total: 4.38s	remaining: 1.95s
# 173:	total: 4.41s	remaining: 1.92s
# 174:	total: 4.43s	remaining: 1.9s
# 175:	total: 4.46s	remaining: 1.88s
# 176:	total: 4.49s	remaining: 1.85s
# 177:	total: 4.51s	remaining: 1.82s
# 178:	total: 4.54s	remaining: 1.8s
# 179:	total: 4.57s	remaining: 1.78s
# 180:	total: 4.6s	remaining: 1.75s
# 181:	total: 4.62s	remaining: 1.73s
# 182:	total: 4.65s	remaining: 1.7s
# 183:	total: 4.67s	remaining: 1.68s
# 184:	total: 4.7s	remaining: 1.65s
# 185:	total: 4.73s	remaining: 1.63s
# 186:	total: 4.76s	remaining: 1.6s
# 187:	total: 4.78s	remaining: 1.58s
# 188:	total: 4.81s	remaining: 1.55s
# 189:	total: 4.84s	remaining: 1.53s
# 190:	total: 4.84s	remaining: 1.5s
# 191:	total: 4.87s	remaining: 1.47s
# 192:	total: 4.9s	remaining: 1.45s
# 193:	total: 4.92s	remaining: 1.42s
# 194:	total: 4.95s	remaining: 1.4s
# 195:	total: 4.97s	remaining: 1.37s
# 196:	total: 5s	remaining: 1.34s
# 197:	total: 5.03s	remaining: 1.32s
# 198:	total: 5.05s	remaining: 1.29s
# 199:	total: 5.08s	remaining: 1.27s
# 200:	total: 5.1s	remaining: 1.24s
# 201:	total: 5.13s	remaining: 1.22s
# 202:	total: 5.16s	remaining: 1.19s
# 203:	total: 5.18s	remaining: 1.17s
# 204:	total: 5.21s	remaining: 1.14s
# 205:	total: 5.24s	remaining: 1.12s
# 206:	total: 5.27s	remaining: 1.09s
# 207:	total: 5.29s	remaining: 1.07s
# 208:	total: 5.29s	remaining: 1.04s
# 209:	total: 5.32s	remaining: 1.01s
# 210:	total: 5.35s	remaining: 988ms
# 211:	total: 5.37s	remaining: 963ms
# 212:	total: 5.4s	remaining: 938ms
# 213:	total: 5.42s	remaining: 912ms
# 214:	total: 5.42s	remaining: 883ms
# 215:	total: 5.45s	remaining: 858ms
# 216:	total: 5.47s	remaining: 833ms
# 217:	total: 5.5s	remaining: 807ms
# 218:	total: 5.53s	remaining: 782ms
# 219:	total: 5.55s	remaining: 757ms
# 220:	total: 5.58s	remaining: 732ms
# 221:	total: 5.6s	remaining: 706ms
# 222:	total: 5.63s	remaining: 681ms
# 223:	total: 5.65s	remaining: 656ms
# 224:	total: 5.68s	remaining: 631ms
# 225:	total: 5.71s	remaining: 606ms
# 226:	total: 5.71s	remaining: 579ms
# 227:	total: 5.74s	remaining: 554ms
# 228:	total: 5.77s	remaining: 529ms
# 229:	total: 5.77s	remaining: 502ms
# 230:	total: 5.8s	remaining: 477ms
# 231:	total: 5.82s	remaining: 452ms
# 232:	total: 5.85s	remaining: 427ms
# 233:	total: 5.88s	remaining: 402ms
# 234:	total: 5.91s	remaining: 377ms
# 235:	total: 5.93s	remaining: 352ms
# 236:	total: 5.96s	remaining: 327ms
# 237:	total: 5.99s	remaining: 302ms
# 238:	total: 6.01s	remaining: 277ms
# 239:	total: 6.04s	remaining: 252ms
# 240:	total: 6.07s	remaining: 227ms
# 241:	total: 6.1s	remaining: 202ms
# 242:	total: 6.13s	remaining: 177ms
# 243:	total: 6.16s	remaining: 151ms
# 244:	total: 6.18s	remaining: 126ms
# 245:	total: 6.18s	remaining: 101ms
# 246:	total: 6.21s	remaining: 75.4ms
# 247:	total: 6.24s	remaining: 50.3ms
# 248:	total: 6.26s	remaining: 25.1ms
# 249:	total: 6.29s	remaining: 0us

# %%
lr_cv = LogisticRegressionCV(max_iter=1000, scoring = 'roc_auc', refit=True) 

lr_cv.fit(X_train, y_train)
y_train_predicted_lr_cv = lr_cv.predict_proba(X_train)[:, 1]
y_test_predicted_lr_cv = lr_cv.predict_proba(X_test)[:, 1]

# %% [markdown]
# ## Сначала посмотрим на результаты logistic regression:

# %%
test_and_draw(y_train_predicted_lr, y_test_predicted_lr)

# %% [markdown]
# ## Теперь Catboost:

# %%
test_and_draw(y_train_predicted_cb, y_test_predicted_cb)

# %% [markdown]
# ## И Log.regressionCV

# %%
test_and_draw(y_train_predicted_lr_cv, y_test_predicted_lr_cv)

# %% [markdown]
# # К сожалению из-за каких то ошибок мне не удалось запустить алгоритм случайного леса( По итогу выходит что логистическая регрессия с параметром С большим 1 одинаково хорошо работает. Catboost выдал отличные результаты на тренировочном датасете но чуть хуже чем lr на тренировочном
